# %%
# !pip install ucimlrepo
# !pip install libsvm-official

# %%
import numpy as np
import time
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import roc_auc_score, confusion_matrix
from libsvm.svmutil import svm_problem, svm_parameter, svm_train, svm_predict
from ucimlrepo import fetch_ucirepo

np.random.seed(42)

class CSASVM:
    def __init__(self, population_size=8, max_generations=125, clone_factor=1, alpha=0.5):
        self.population_size = population_size
        self.max_generations = max_generations
        self.clone_factor = clone_factor   
        self.alpha = alpha           

        self.C_bounds = (-5, 15)
        self.gamma_bounds = (-15, 1)

    def initialize_population(self):
        pop = []
        for _ in range(self.population_size):
            logC = np.random.uniform(*self.C_bounds)
            logG = np.random.uniform(*self.gamma_bounds)
            pop.append([logC, logG])
        return np.array(pop)

    def affinity(self, logC, logG, X, y):
        C = 2 ** logC
        gamma = 2 ** logG
        prob = svm_problem(y.tolist(), X.tolist())
        param = svm_parameter(f'-s 0 -t 2 -c {C} -g {gamma} -v 5 -q')
        acc = svm_train(prob, param)   
        return acc / 100.0

    def search(self, X, y):
        population = self.initialize_population()
        best_affinity = -np.inf
        best_solution = None

        for _ in range(self.max_generations):
            affinities = np.array([
                self.affinity(ind[0], ind[1], X, y)
                for ind in population
            ])

            # Sort by affinity (descending)
            idx = np.argsort(-affinities)
            population = population[idx]
            affinities = affinities[idx]

            # Elitism
            if affinities[0] > best_affinity:
                best_affinity = affinities[0]
                best_solution = population[0].copy()

            # Selection (top half)
            selected = population[:self.population_size // 2]
            selected_aff = affinities[:self.population_size // 2]

            clones = []
            for ind, aff in zip(selected, selected_aff):
                n_clones = self.clone_factor  
                for _ in range(n_clones):
                    clone = ind.copy()

                    sigma = self.alpha / (aff + 1e-6)
                    clone[0] += np.random.normal(0, sigma)
                    clone[1] += np.random.normal(0, sigma)
                    clone[0] = np.clip(clone[0], *self.C_bounds)
                    clone[1] = np.clip(clone[1], *self.gamma_bounds)
                    clones.append(clone)

            clones = np.array(clones)

            clone_aff = np.array([
                self.affinity(ind[0], ind[1], X, y)
                for ind in clones
            ])

            best_idx = np.argsort(-clone_aff)[:self.population_size]
            population = clones[best_idx]

        best_C = 2 ** best_solution[0]
        best_gamma = 2 ** best_solution[1]
        return best_C, best_gamma, best_affinity

    def fit(self, X, y):
        df = pd.DataFrame(X)
        df.fillna(df.mean(), inplace=True)
        X = df.values

        all_acc, all_auc, all_sens, all_spec = [], [], [], []
        run_times = []

        for run in range(10):
            outer_cv = StratifiedKFold(n_splits=10, shuffle=True, random_state=42 + run)
            fold_times = []

            for train_idx, test_idx in outer_cv.split(X, y):
                start = time.time()

                X_train, X_test = X[train_idx], X[test_idx]
                y_train, y_test = y[train_idx], y[test_idx]

                scaler = MinMaxScaler((-1, 1))
                X_train = scaler.fit_transform(X_train)
                X_test = scaler.transform(X_test)

                best_C, best_gamma, _ = self.search(X_train, y_train)

                prob = svm_problem(y_train.tolist(), X_train.tolist())
                param = svm_parameter(f'-s 0 -t 2 -c {best_C} -g {best_gamma} -b 1 -q')
                model = svm_train(prob, param)

                p_label, p_acc, p_val = svm_predict(
                    y_test.tolist(), X_test.tolist(), model, '-b 1 -q'
                )

                acc = p_acc[0] / 100
                all_acc.append(acc)

                probs = [v[0] for v in p_val]
                all_auc.append(roc_auc_score(y_test, probs))

                tn, fp, fn, tp = confusion_matrix(y_test, p_label).ravel()
                all_sens.append(tp / (tp + fn))
                all_spec.append(tn / (tn + fp))

                fold_times.append(time.time() - start)

            run_times.append(sum(fold_times))

        return {
            'acc_mean': np.mean(all_acc), 'acc_std': np.std(all_acc),
            'auc_mean': np.mean(all_auc), 'auc_std': np.std(all_auc),
            'sens_mean': np.mean(all_sens), 'sens_std': np.std(all_sens),
            'spec_mean': np.mean(all_spec), 'spec_std': np.std(all_spec),
            'run_times': run_times,
            'per_run_acc': np.array(all_acc).reshape(10, 10).mean(axis=1)
        }


# Running on Pima Indians diabetes
diabetes_data = pd.read_csv('Pima Indians diabetes (Pima).csv')
X = diabetes_data.iloc[:, :-1].values
y = diabetes_data.iloc[:, -1].values

model = CSASVM()
result = model.fit(X, y)

print(f"Accuracy: {result['acc_mean']:.4f} ± {result['acc_std']:.4f}")
print(f"AUC: {result['auc_mean']:.4f} ± {result['auc_std']:.4f}")
print(f"Sensitivity: {result['sens_mean']:.4f} ± {result['sens_std']:.4f}")
print(f"Specificity: {result['spec_mean']:.4f} ± {result['spec_std']:.4f}")

plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
plt.plot(range(1,11), result['per_run_acc'], 'o-')
plt.title('Accuracy per Run')

plt.subplot(1,2,2)
plt.bar(range(1,11), result['run_times'])
plt.title('CPU Time per Run')

plt.tight_layout()
plt.show()
# Out:
# Cross Validation Accuracy = 74.3849%
# Cross Validation Accuracy = 75.5427%
# Cross Validation Accuracy = 65.123%
# Cross Validation Accuracy = 69.754%
# Cross Validation Accuracy = 76.1216%
# Cross Validation Accuracy = 65.123%
# Cross Validation Accuracy = 75.8321%
# Cross Validation Accuracy = 65.123%
# Cross Validation Accuracy = 76.1216%
# Cross Validation Accuracy = 77.5687%
# Cross Validation Accuracy = 75.6874%
# Cross Validation Accuracy = 75.9768%
# Cross Validation Accuracy = 77.2793%
# Cross Validation Accuracy = 76.7004%
# Cross Validation Accuracy = 73.3719%
# Cross Validation Accuracy = 75.9768%
# Cross Validation Accuracy = 76.411%
# Cross Validation Accuracy = 76.5557%
# Cross Validation Accuracy = 76.1216%
# Cross Validation Accuracy = 75.1085%
# Cross Validation Accuracy = 76.8452%
# Cross Validation Accuracy = 76.9899%
# Cross Validation Accuracy = 75.9768%
# Cross Validation Accuracy = 74.2402%
# Cross Validation Accuracy = 77.424%
# Cross Validation Accuracy = 76.1216%
# Cross Validation Accuracy = 76.1216%
# Cross Validation Accuracy = 74.6744%
# Cross Validation Accuracy = 76.5557%
# Cross Validation Accuracy = 76.5557%
# Cross Validation Accuracy = 76.2663%
# Cross Validation Accuracy = 77.5687%
# Cross Validation Accuracy = 76.8452%
# Cross Validation Accuracy = 77.424%
# Cross Validation Accuracy = 75.2533%
# Cross Validation Accuracy = 76.411%
# Cross Validation Accuracy = 76.2663%
# Cross Validation Accuracy = 76.7004%
# Cross Validation Accuracy = 76.8452%
# Cross Validation Accuracy = 76.7004%
# Cross Validation Accuracy = 77.424%
# Cross Validation Accuracy = 76.411%
# Cross Validation Accuracy = 76.7004%
# Cross Validation Accuracy = 76.5557%
# Cross Validation Accuracy = 76.7004%
# Cross Validation Accuracy = 76.2663%
# Cross Validation Accuracy = 77.5687%
# Cross Validation Accuracy = 75.6874%
# Cross Validation Accuracy = 77.424%
# Cross Validation Accuracy = 75.9768%
# Cross Validation Accuracy = 76.7004%
# Cross Validation Accuracy = 74.9638%
# Cross Validation Accuracy = 76.9899%
# Cross Validation Accuracy = 77.1346%
# Cross Validation Accuracy = 76.2663%
# Cross Validation Accuracy = 76.411%
# Cross Validation Accuracy = 77.2793%
# Cross Validation Accuracy = 78.0029%
# Cross Validation Accuracy = 75.5427%
# Cross Validation Accuracy = 76.5557%
# Cross Validation Accuracy = 78.0029%
# Cross Validation Accuracy = 76.5557%
# Cross Validation Accuracy = 75.2533%
# Cross Validation Accuracy = 76.1216%
# Cross Validation Accuracy = 77.8582%
# Cross Validation Accuracy = 76.1216%
# Cross Validation Accuracy = 73.8061%
# Cross Validation Accuracy = 75.398%
# Cross Validation Accuracy = 76.9899%
# Cross Validation Accuracy = 76.1216%
# Cross Validation Accuracy = 75.6874%
# Cross Validation Accuracy = 73.3719%
# Cross Validation Accuracy = 77.8582%
# Cross Validation Accuracy = 77.1346%
# Cross Validation Accuracy = 77.5687%
# Cross Validation Accuracy = 73.9508%
# Cross Validation Accuracy = 76.7004%
# Cross Validation Accuracy = 76.9899%
# Cross Validation Accuracy = 77.5687%
# Cross Validation Accuracy = 74.5297%
# Cross Validation Accuracy = 77.2793%
# Cross Validation Accuracy = 76.411%
# Cross Validation Accuracy = 77.7135%
# Cross Validation Accuracy = 72.0695%
# Cross Validation Accuracy = 76.9899%
# Cross Validation Accuracy = 76.9899%
# Cross Validation Accuracy = 75.8321%
# Cross Validation Accuracy = 73.8061%
# Cross Validation Accuracy = 76.2663%
# Cross Validation Accuracy = 77.424%
# Cross Validation Accuracy = 76.411%
# Cross Validation Accuracy = 74.3849%
# Cross Validation Accuracy = 77.2793%
# Cross Validation Accuracy = 75.5427%
# Cross Validation Accuracy = 76.9899%
# Cross Validation Accuracy = 73.0825%
# Cross Validation Accuracy = 76.1216%
# Cross Validation Accuracy = 74.3849%
# Cross Validation Accuracy = 76.5557%
# Cross Validation Accuracy = 72.0695%
# Cross Validation Accuracy = 75.9768%
# Cross Validation Accuracy = 76.5557%
# Cross Validation Accuracy = 75.2533%
# Cross Validation Accuracy = 70.0434%
# Cross Validation Accuracy = 77.5687%
# Cross Validation Accuracy = 76.2663%
# Cross Validation Accuracy = 77.5687%
# Cross Validation Accuracy = 71.3459%
# Cross Validation Accuracy = 76.5557%
# Cross Validation Accuracy = 76.8452%
# Cross Validation Accuracy = 76.7004%
# Cross Validation Accuracy = 71.9247%
# Cross Validation Accuracy = 77.2793%
# Cross Validation Accuracy = 76.2663%
# Cross Validation Accuracy = 77.424%
# Cross Validation Accuracy = 72.6483%
# Cross Validation Accuracy = 76.9899%
# Cross Validation Accuracy = 77.424%
# Cross Validation Accuracy = 75.6874%
# Cross Validation Accuracy = 71.9247%
# Cross Validation Accuracy = 77.1346%
# Cross Validation Accuracy = 78.1476%
# Cross Validation Accuracy = 77.2793%
# Cross Validation Accuracy = 73.6614%
# Cross Validation Accuracy = 76.9899%
# Cross Validation Accuracy = 76.1216%
# Cross Validation Accuracy = 77.424%
# Cross Validation Accuracy = 72.7931%
# Cross Validation Accuracy = 76.5557%
# Cross Validation Accuracy = 76.7004%
# Cross Validation Accuracy = 75.8321%
# Cross Validation Accuracy = 74.8191%
# Cross Validation Accuracy = 77.424%
# Cross Validation Accuracy = 77.424%
# Cross Validation Accuracy = 75.9768%
# Cross Validation Accuracy = 73.8061%
# Cross Validation Accuracy = 77.424%
# Cross Validation Accuracy = 78.1476%
# Cross Validation Accuracy = 76.1216%
# Cross Validation Accuracy = 75.6874%
# Cross Validation Accuracy = 76.5557%
# Cross Validation Accuracy = 76.7004%
# Cross Validation Accuracy = 76.411%
# Cross Validation Accuracy = 75.8321%
# Cross Validation Accuracy = 77.1346%
# Cross Validation Accuracy = 77.424%
# Cross Validation Accuracy = 75.6874%
# Cross Validation Accuracy = 76.8452%
# Cross Validation Accuracy = 77.424%
# Cross Validation Accuracy = 77.7135%
# Cross Validation Accuracy = 75.8321%
# Cross Validation Accuracy = 76.5557%
# Cross Validation Accuracy = 77.5687%
# Cross Validation Accuracy = 77.5687%
# Cross Validation Accuracy = 75.5427%
# Cross Validation Accuracy = 75.6874%
# Cross Validation Accuracy = 76.7004%
# Cross Validation Accuracy = 76.8452%
# Cross Validation Accuracy = 75.8321%
# Cross Validation Accuracy = 76.5557%
# Cross Validation Accuracy = 76.411%
# Cross Validation Accuracy = 77.5687%
# Cross Validation Accuracy = 76.411%
# Cross Validation Accuracy = 77.1346%
# Cross Validation Accuracy = 76.5557%
# Cross Validation Accuracy = 75.8321%
# Cross Validation Accuracy = 77.5687%
# Cross Validation Accuracy = 76.2663%
# Cross Validation Accuracy = 76.8452%
# Cross Validation Accuracy = 76.7004%
# Cross Validation Accuracy = 75.398%
# Cross Validation Accuracy = 75.2533%
# Cross Validation Accuracy = 76.8452%
# Cross Validation Accuracy = 76.7004%
# Cross Validation Accuracy = 76.5557%
# Cross Validation Accuracy = 74.2402%
# Cross Validation Accuracy = 77.1346%
# Cross Validation Accuracy = 75.1085%
# Cross Validation Accuracy = 73.5166%
# Cross Validation Accuracy = 76.8452%
# Cross Validation Accuracy = 76.8452%
# Cross Validation Accuracy = 73.8061%
# Cross Validation Accuracy = 76.5557%
# Cross Validation Accuracy = 76.5557%
# Cross Validation Accuracy = 76.9899%
# Cross Validation Accuracy = 76.7004%
# Cross Validation Accuracy = 75.6874%
# Cross Validation Accuracy = 74.6744%
# Cross Validation Accuracy = 76.2663%
# Cross Validation Accuracy = 75.6874%
# Cross Validation Accuracy = 75.398%
# Cross Validation Accuracy = 74.2402%
# Cross Validation Accuracy = 75.5427%
# Cross Validation Accuracy = 77.424%
# Cross Validation Accuracy = 75.6874%
# Cross Validation Accuracy = 72.5036%
# Cross Validation Accuracy = 76.7004%
# Cross Validation Accuracy = 74.2402%
# Cross Validation Accuracy = 75.8321%
# Cross Validation Accuracy = 74.6744%
# Cross Validation Accuracy = 77.2793%
# Cross Validation Accuracy = 77.5687%
# Cross Validation Accuracy = 69.0304%
# Cross Validation Accuracy = 73.8061%
# Cross Validation Accuracy = 77.424%
# Cross Validation Accuracy = 76.5557%
# Cross Validation Accuracy = 74.0955%
# Cross Validation Accuracy = 71.2012%
# Cross Validation Accuracy = 77.1346%
# Cross Validation Accuracy = 76.2663%
# Cross Validation Accuracy = 74.2402%
# Cross Validation Accuracy = 67.5832%
# Cross Validation Accuracy = 77.7135%
# Cross Validation Accuracy = 76.9899%
# Cross Validation Accuracy = 74.2402%
# Cross Validation Accuracy = 70.0434%
# Cross Validation Accuracy = 76.7004%
# Cross Validation Accuracy = 76.411%
# Cross Validation Accuracy = 76.411%
# Cross Validation Accuracy = 71.6353%
# Cross Validation Accuracy = 76.7004%
# Cross Validation Accuracy = 76.411%
# Cross Validation Accuracy = 74.6744%
# Cross Validation Accuracy = 72.3589%
# Cross Validation Accuracy = 77.1346%
# Cross Validation Accuracy = 76.9899%
# Cross Validation Accuracy = 75.2533%
# Cross Validation Accuracy = 67.8726%
# Cross Validation Accuracy = 77.424%
# Cross Validation Accuracy = 77.424%
# Cross Validation Accuracy = 75.9768%
# Cross Validation Accuracy = 68.8857%
# Cross Validation Accuracy = 76.7004%
# Cross Validation Accuracy = 76.8452%
# Cross Validation Accuracy = 75.398%
# Cross Validation Accuracy = 68.0174%
# Cross Validation Accuracy = 77.7135%
# Cross Validation Accuracy = 77.5687%
# Cross Validation Accuracy = 75.8321%
# Cross Validation Accuracy = 69.4645%
# Cross Validation Accuracy = 77.7135%
# Cross Validation Accuracy = 76.1216%
# Cross Validation Accuracy = 75.5427%
# Cross Validation Accuracy = 68.741%
# Cross Validation Accuracy = 77.2793%
# Cross Validation Accuracy = 76.1216%
# Cross Validation Accuracy = 75.398%
# Cross Validation Accuracy = 68.1621%
# Cross Validation Accuracy = 76.5557%
# Cross Validation Accuracy = 67.8726%
# Cross Validation Accuracy = 74.3849%
# Cross Validation Accuracy = 67.1491%
# Cross Validation Accuracy = 76.7004%
# Cross Validation Accuracy = 75.398%
# Cross Validation Accuracy = 67.5832%
# Cross Validation Accuracy = 68.0174%
# Cross Validation Accuracy = 77.7135%
# Cross Validation Accuracy = 75.2533%
# Cross Validation Accuracy = 70.0434%
# Cross Validation Accuracy = 69.1751%
# Cross Validation Accuracy = 77.1346%
# Cross Validation Accuracy = 75.2533%
# Cross Validation Accuracy = 70.6223%
# Cross Validation Accuracy = 69.0304%
# Cross Validation Accuracy = 77.2793%
# Cross Validation Accuracy = 74.6744%
# Cross Validation Accuracy = 71.78%
# Cross Validation Accuracy = 65.7019%
# Cross Validation Accuracy = 76.8452%
# Cross Validation Accuracy = 75.5427%
# Cross Validation Accuracy = 70.1881%
# Cross Validation Accuracy = 65.5572%
# Cross Validation Accuracy = 76.8452%
# Cross Validation Accuracy = 76.7004%
# Cross Validation Accuracy = 67.7279%
# Cross Validation Accuracy = 67.5832%
# Cross Validation Accuracy = 77.5687%
# Cross Validation Accuracy = 76.411%
# Cross Validation Accuracy = 69.1751%
# Cross Validation Accuracy = 68.3068%
# Cross Validation Accuracy = 77.2793%
# Cross Validation Accuracy = 76.5557%
# Cross Validation Accuracy = 69.1751%
# Cross Validation Accuracy = 65.2677%
# Cross Validation Accuracy = 77.1346%
# Cross Validation Accuracy = 75.6874%
# Cross Validation Accuracy = 68.741%
# Cross Validation Accuracy = 65.123%
# Cross Validation Accuracy = 76.8452%
# Cross Validation Accuracy = 76.411%
# Cross Validation Accuracy = 67.4385%
# Cross Validation Accuracy = 73.9508%
# Cross Validation Accuracy = 77.5687%
# Cross Validation Accuracy = 75.9768%
# Cross Validation Accuracy = 73.6614%
# Cross Validation Accuracy = 65.5572%
# Cross Validation Accuracy = 76.2663%
# Cross Validation Accuracy = 75.398%
# Cross Validation Accuracy = 73.8061%
# Cross Validation Accuracy = 66.8596%
# Cross Validation Accuracy = 76.411%
# Cross Validation Accuracy = 75.6874%
# Cross Validation Accuracy = 73.9508%
# Cross Validation Accuracy = 68.4515%
# Cross Validation Accuracy = 76.411%
# Cross Validation Accuracy = 74.8191%
# Cross Validation Accuracy = 76.7004%
# Cross Validation Accuracy = 67.2938%
# Cross Validation Accuracy = 75.6874%
# Cross Validation Accuracy = 76.2663%
# Cross Validation Accuracy = 75.9768%
# Cross Validation Accuracy = 67.4385%
# Cross Validation Accuracy = 76.7004%
# Cross Validation Accuracy = 74.9638%
# Cross Validation Accuracy = 76.7004%
# Cross Validation Accuracy = 68.8857%
# Cross Validation Accuracy = 76.8452%
# Cross Validation Accuracy = 77.424%
# Cross Validation Accuracy = 75.398%
# Cross Validation Accuracy = 67.1491%
# Cross Validation Accuracy = 73.5166%
# Cross Validation Accuracy = 77.2793%
# Cross Validation Accuracy = 74.9638%
# Cross Validation Accuracy = 67.1491%
# Cross Validation Accuracy = 77.1346%
# Cross Validation Accuracy = 74.2402%
# Cross Validation Accuracy = 74.6744%
# Cross Validation Accuracy = 67.5832%
# Cross Validation Accuracy = 77.2793%
# Cross Validation Accuracy = 76.1216%
# Cross Validation Accuracy = 76.5557%
# Cross Validation Accuracy = 67.1491%
# Cross Validation Accuracy = 77.424%
# Cross Validation Accuracy = 74.2402%
# Cross Validation Accuracy = 76.1216%
# Cross Validation Accuracy = 70.767%
# Cross Validation Accuracy = 77.424%
# Cross Validation Accuracy = 76.411%
# Cross Validation Accuracy = 76.2663%
# Cross Validation Accuracy = 72.6483%
# Cross Validation Accuracy = 76.8452%
# Cross Validation Accuracy = 75.9768%
# Cross Validation Accuracy = 75.1085%
# Cross Validation Accuracy = 70.3329%
# Cross Validation Accuracy = 76.2663%
# Cross Validation Accuracy = 78.0029%
# Cross Validation Accuracy = 75.6874%
# Cross Validation Accuracy = 73.6614%
# Cross Validation Accuracy = 77.2793%
# Cross Validation Accuracy = 76.8452%
# Cross Validation Accuracy = 74.3849%
# Cross Validation Accuracy = 73.5166%
# Cross Validation Accuracy = 77.2793%
# Cross Validation Accuracy = 77.1346%
# Cross Validation Accuracy = 74.2402%
# Cross Validation Accuracy = 73.0825%
# Cross Validation Accuracy = 77.1346%
# Cross Validation Accuracy = 77.1346%
# Cross Validation Accuracy = 73.3719%
# Cross Validation Accuracy = 72.6483%
# Cross Validation Accuracy = 77.2793%
# Cross Validation Accuracy = 76.5557%
# Cross Validation Accuracy = 75.9768%
# Cross Validation Accuracy = 70.3329%
# Cross Validation Accuracy = 77.5687%
# Cross Validation Accuracy = 77.7135%
# Cross Validation Accuracy = 73.3719%
# Cross Validation Accuracy = 71.4906%
# Cross Validation Accuracy = 77.1346%
# Cross Validation Accuracy = 77.2793%
# Cross Validation Accuracy = 75.2533%
# Cross Validation Accuracy = 69.3198%
# Cross Validation Accuracy = 77.7135%
# Cross Validation Accuracy = 76.7004%
# Cross Validation Accuracy = 75.6874%
# Cross Validation Accuracy = 70.9117%
# Cross Validation Accuracy = 77.7135%
# Cross Validation Accuracy = 78.1476%
# Cross Validation Accuracy = 75.2533%
# Cross Validation Accuracy = 68.5962%
# Cross Validation Accuracy = 76.7004%
# Cross Validation Accuracy = 77.1346%
# Cross Validation Accuracy = 76.1216%
# Cross Validation Accuracy = 70.3329%
# Cross Validation Accuracy = 77.2793%
# Cross Validation Accuracy = 77.1346%
# Cross Validation Accuracy = 73.3719%
# Cross Validation Accuracy = 68.1621%
# Cross Validation Accuracy = 76.5557%
# Cross Validation Accuracy = 76.8452%
# Cross Validation Accuracy = 72.3589%
# Cross Validation Accuracy = 68.8857%
# Cross Validation Accuracy = 76.5557%
# Cross Validation Accuracy = 77.424%
# Cross Validation Accuracy = 75.5427%
# Cross Validation Accuracy = 69.3198%
# Cross Validation Accuracy = 77.1346%
# Cross Validation Accuracy = 76.2663%
# Cross Validation Accuracy = 76.1216%
# Cross Validation Accuracy = 66.2808%
# Cross Validation Accuracy = 77.424%
# Cross Validation Accuracy = 77.2793%
# Cross Validation Accuracy = 75.5427%
# Cross Validation Accuracy = 69.0304%
# Cross Validation Accuracy = 76.9899%
# Cross Validation Accuracy = 77.7135%
# Cross Validation Accuracy = 74.8191%
# Cross Validation Accuracy = 69.4645%
# Cross Validation Accuracy = 76.8452%
# Cross Validation Accuracy = 76.7004%
# Cross Validation Accuracy = 72.0695%
# Cross Validation Accuracy = 70.9117%
# Cross Validation Accuracy = 76.7004%
# Cross Validation Accuracy = 76.8452%
# Cross Validation Accuracy = 73.8061%
# Cross Validation Accuracy = 69.4645%
# Cross Validation Accuracy = 76.1216%
# Cross Validation Accuracy = 75.9768%
# Cross Validation Accuracy = 69.6093%
# Cross Validation Accuracy = 68.5962%
# Cross Validation Accuracy = 76.1216%
# Cross Validation Accuracy = 77.8582%
# Cross Validation Accuracy = 67.8726%
# Cross Validation Accuracy = 70.4776%
# Cross Validation Accuracy = 76.9899%
# Cross Validation Accuracy = 76.9899%
# Cross Validation Accuracy = 66.4255%
# Cross Validation Accuracy = 69.0304%
# Cross Validation Accuracy = 77.1346%
# Cross Validation Accuracy = 77.5687%
# Cross Validation Accuracy = 66.2808%
# Cross Validation Accuracy = 67.8726%
# Cross Validation Accuracy = 75.9768%
# Cross Validation Accuracy = 77.2793%
# Cross Validation Accuracy = 65.123%
# Cross Validation Accuracy = 70.3329%
# Cross Validation Accuracy = 77.7135%
# Cross Validation Accuracy = 77.7135%
# Cross Validation Accuracy = 70.9117%
# Cross Validation Accuracy = 68.5962%
# Cross Validation Accuracy = 76.9899%
# Cross Validation Accuracy = 76.7004%
# Cross Validation Accuracy = 73.2272%
# Cross Validation Accuracy = 67.8726%
# Cross Validation Accuracy = 76.8452%
# Cross Validation Accuracy = 76.7004%
# Cross Validation Accuracy = 73.8061%
# Cross Validation Accuracy = 68.1621%
# Cross Validation Accuracy = 75.6874%
# Cross Validation Accuracy = 76.9899%
# Cross Validation Accuracy = 73.6614%
# Cross Validation Accuracy = 70.767%
# Cross Validation Accuracy = 76.411%
# Cross Validation Accuracy = 76.1216%
# Cross Validation Accuracy = 75.1085%
# Cross Validation Accuracy = 70.3329%
# Cross Validation Accuracy = 77.1346%
# Cross Validation Accuracy = 76.1216%
# Cross Validation Accuracy = 75.6874%
# Cross Validation Accuracy = 68.1621%
# Cross Validation Accuracy = 76.2663%
# Cross Validation Accuracy = 77.1346%
# Cross Validation Accuracy = 74.9638%
# Cross Validation Accuracy = 65.7019%
# Cross Validation Accuracy = 74.0955%
# Cross Validation Accuracy = 76.5557%
# Cross Validation Accuracy = 74.0955%
# Cross Validation Accuracy = 66.7149%
# Cross Validation Accuracy = 77.2793%
# Cross Validation Accuracy = 73.0825%
# Cross Validation Accuracy = 72.0695%
# Cross Validation Accuracy = 67.8726%
# Cross Validation Accuracy = 76.7004%
# Cross Validation Accuracy = 77.1346%
# Cross Validation Accuracy = 74.6744%
# Cross Validation Accuracy = 65.7019%
# Cross Validation Accuracy = 77.5687%
# Cross Validation Accuracy = 77.1346%
# Cross Validation Accuracy = 75.2533%
# Cross Validation Accuracy = 67.0043%
# Cross Validation Accuracy = 77.8582%
# Cross Validation Accuracy = 77.424%
# Cross Validation Accuracy = 73.0825%
# Cross Validation Accuracy = 64.5441%
# Cross Validation Accuracy = 77.424%
# Cross Validation Accuracy = 77.5687%
# Cross Validation Accuracy = 73.2272%
# Cross Validation Accuracy = 69.0304%
# Cross Validation Accuracy = 77.1346%
# Cross Validation Accuracy = 77.8582%
# Cross Validation Accuracy = 72.9378%
# Cross Validation Accuracy = 66.136%
# Cross Validation Accuracy = 77.7135%
# Cross Validation Accuracy = 77.1346%
# Cross Validation Accuracy = 73.6614%
# Cross Validation Accuracy = 67.5832%
# Cross Validation Accuracy = 76.9899%
# Cross Validation Accuracy = 77.424%
# Cross Validation Accuracy = 75.1085%
# Cross Validation Accuracy = 68.741%
# Cross Validation Accuracy = 76.7004%
# Cross Validation Accuracy = 77.5687%
# Cross Validation Accuracy = 74.2402%
# Cross Validation Accuracy = 69.754%
# Cross Validation Accuracy = 75.8321%
# Cross Validation Accuracy = 76.2663%
# Cross Validation Accuracy = 75.6874%
# Cross Validation Accuracy = 70.1881%
# Cross Validation Accuracy = 77.2793%
# Cross Validation Accuracy = 77.8582%
# Cross Validation Accuracy = 74.5297%
# Cross Validation Accuracy = 66.5702%
# Cross Validation Accuracy = 76.9899%
# Cross Validation Accuracy = 76.9899%
# Cross Validation Accuracy = 75.398%
# Cross Validation Accuracy = 69.1751%
# Cross Validation Accuracy = 76.7004%
# Cross Validation Accuracy = 77.1346%
# Cross Validation Accuracy = 76.1216%
# Cross Validation Accuracy = 64.9783%
# Cross Validation Accuracy = 77.7135%
# Cross Validation Accuracy = 76.9899%
# Cross Validation Accuracy = 75.398%
# Cross Validation Accuracy = 69.4645%
# Cross Validation Accuracy = 77.2793%
# Cross Validation Accuracy = 77.2793%
# Cross Validation Accuracy = 75.398%
# Cross Validation Accuracy = 70.1881%
# Cross Validation Accuracy = 76.9899%
# Cross Validation Accuracy = 77.1346%
# Cross Validation Accuracy = 76.8452%
# Cross Validation Accuracy = 69.3198%
# Cross Validation Accuracy = 77.424%
# Cross Validation Accuracy = 77.1346%
# Cross Validation Accuracy = 76.7004%
# Cross Validation Accuracy = 70.3329%
# Cross Validation Accuracy = 77.1346%
# Cross Validation Accuracy = 75.6874%
# Cross Validation Accuracy = 76.9899%
# Cross Validation Accuracy = 70.6223%
# Cross Validation Accuracy = 77.424%
# Cross Validation Accuracy = 76.1216%
# Cross Validation Accuracy = 76.5557%
# Cross Validation Accuracy = 70.6223%
# Cross Validation Accuracy = 77.1346%
# Cross Validation Accuracy = 76.8452%
# Cross Validation Accuracy = 76.1216%
# Cross Validation Accuracy = 70.767%
# Cross Validation Accuracy = 77.424%
# Cross Validation Accuracy = 76.5557%
# Cross Validation Accuracy = 76.411%
# Cross Validation Accuracy = 69.3198%
# Cross Validation Accuracy = 77.2793%
# Cross Validation Accuracy = 77.424%
# Cross Validation Accuracy = 76.7004%
# Cross Validation Accuracy = 68.8857%
# Cross Validation Accuracy = 77.5687%
# Cross Validation Accuracy = 77.1346%
# Cross Validation Accuracy = 74.6744%
# Cross Validation Accuracy = 72.6483%
# Cross Validation Accuracy = 76.7004%
# Cross Validation Accuracy = 70.767%
# Cross Validation Accuracy = 76.7004%
# Cross Validation Accuracy = 68.8857%
# Cross Validation Accuracy = 77.5687%
# Cross Validation Accuracy = 76.411%
# Cross Validation Accuracy = 69.6093%
# Cross Validation Accuracy = 68.8857%
# Cross Validation Accuracy = 76.7004%
# Cross Validation Accuracy = 77.424%
# Cross Validation Accuracy = 74.9638%
# Cross Validation Accuracy = 67.0043%
# Cross Validation Accuracy = 76.9899%
# Cross Validation Accuracy = 76.9899%
# Cross Validation Accuracy = 75.8321%
# Cross Validation Accuracy = 69.3198%
# Cross Validation Accuracy = 77.5687%
# Cross Validation Accuracy = 77.424%
# Cross Validation Accuracy = 75.8321%
# Cross Validation Accuracy = 70.767%
# Cross Validation Accuracy = 75.8321%
# Cross Validation Accuracy = 77.1346%
# Cross Validation Accuracy = 76.1216%
# Cross Validation Accuracy = 69.6093%
# Cross Validation Accuracy = 77.1346%
# Cross Validation Accuracy = 74.8191%
# Cross Validation Accuracy = 75.5427%
# Cross Validation Accuracy = 69.8987%
# Cross Validation Accuracy = 76.5557%
# Cross Validation Accuracy = 76.8452%
# Cross Validation Accuracy = 74.9638%
# Cross Validation Accuracy = 68.741%
# Cross Validation Accuracy = 76.9899%
# Cross Validation Accuracy = 77.1346%
# Cross Validation Accuracy = 74.9638%
# Cross Validation Accuracy = 67.8726%
# Cross Validation Accuracy = 76.2663%
# Cross Validation Accuracy = 76.8452%
# Cross Validation Accuracy = 72.9378%
# Cross Validation Accuracy = 66.5702%
# Cross Validation Accuracy = 76.8452%
# Cross Validation Accuracy = 77.424%
# Cross Validation Accuracy = 72.7931%
# Cross Validation Accuracy = 66.7149%
# Cross Validation Accuracy = 76.9899%
# Cross Validation Accuracy = 77.1346%
# Cross Validation Accuracy = 72.5036%
# Cross Validation Accuracy = 65.8466%
# Cross Validation Accuracy = 77.7135%
# Cross Validation Accuracy = 76.9899%
# Cross Validation Accuracy = 74.9638%
# Cross Validation Accuracy = 69.8987%
# Cross Validation Accuracy = 76.8452%
# Cross Validation Accuracy = 77.2793%
# Cross Validation Accuracy = 75.9768%
# Cross Validation Accuracy = 69.1751%
# Cross Validation Accuracy = 76.7004%
# Cross Validation Accuracy = 75.6874%
# Cross Validation Accuracy = 77.2793%
# Cross Validation Accuracy = 68.4515%
# Cross Validation Accuracy = 76.9899%
# Cross Validation Accuracy = 77.2793%
# Cross Validation Accuracy = 75.9768%
# Cross Validation Accuracy = 65.123%
# Cross Validation Accuracy = 77.424%
# Cross Validation Accuracy = 77.2793%
# Cross Validation Accuracy = 77.424%
# Cross Validation Accuracy = 68.3068%
# Cross Validation Accuracy = 77.8582%
# Cross Validation Accuracy = 75.6874%
# Cross Validation Accuracy = 76.7004%
# Cross Validation Accuracy = 70.3329%
# Cross Validation Accuracy = 76.7004%
# Cross Validation Accuracy = 67.0043%
# Cross Validation Accuracy = 75.1085%
# Cross Validation Accuracy = 72.3589%
# Cross Validation Accuracy = 77.7135%
# Cross Validation Accuracy = 76.2663%
# Cross Validation Accuracy = 72.9378%
# Cross Validation Accuracy = 68.8857%
# Cross Validation Accuracy = 77.8582%
# Cross Validation Accuracy = 75.9768%
# Cross Validation Accuracy = 70.3329%
# Cross Validation Accuracy = 77.5687%
# Cross Validation Accuracy = 76.9899%
# Cross Validation Accuracy = 76.8452%
# Cross Validation Accuracy = 75.5427%
# Cross Validation Accuracy = 71.9247%
# Cross Validation Accuracy = 76.8452%
# Cross Validation Accuracy = 76.9899%
# Cross Validation Accuracy = 75.9768%
# Cross Validation Accuracy = 71.3459%
# Cross Validation Accuracy = 75.5427%
# Cross Validation Accuracy = 76.5557%
# Cross Validation Accuracy = 78.0029%
# Cross Validation Accuracy = 72.0695%
# Cross Validation Accuracy = 76.8452%
# Cross Validation Accuracy = 76.411%
# Cross Validation Accuracy = 77.2793%
# Cross Validation Accuracy = 70.3329%
# Cross Validation Accuracy = 76.8452%
# Cross Validation Accuracy = 76.8452%
# Cross Validation Accuracy = 77.1346%
# Cross Validation Accuracy = 71.0564%
# Cross Validation Accuracy = 76.7004%
# Cross Validation Accuracy = 77.1346%
# Cross Validation Accuracy = 76.5557%
# Cross Validation Accuracy = 69.0304%
# Cross Validation Accuracy = 76.9899%
# Cross Validation Accuracy = 76.7004%
# Cross Validation Accuracy = 77.2793%
# Cross Validation Accuracy = 70.1881%
# Cross Validation Accuracy = 76.411%
# Cross Validation Accuracy = 77.1346%
# Cross Validation Accuracy = 76.9899%
# Cross Validation Accuracy = 69.0304%
# Cross Validation Accuracy = 76.9899%
# Cross Validation Accuracy = 76.411%
# Cross Validation Accuracy = 76.411%
# Cross Validation Accuracy = 69.0304%
# Cross Validation Accuracy = 77.1346%
# Cross Validation Accuracy = 77.5687%
# Cross Validation Accuracy = 75.2533%
# Cross Validation Accuracy = 69.4645%
# Cross Validation Accuracy = 77.2793%
# Cross Validation Accuracy = 76.411%
# Cross Validation Accuracy = 75.398%
# Cross Validation Accuracy = 69.754%
# Cross Validation Accuracy = 76.9899%
# Cross Validation Accuracy = 77.1346%
# Cross Validation Accuracy = 76.7004%
# Cross Validation Accuracy = 66.4255%
# Cross Validation Accuracy = 76.1216%
# Cross Validation Accuracy = 77.5687%
# Cross Validation Accuracy = 75.8321%
# Cross Validation Accuracy = 70.9117%
# Cross Validation Accuracy = 76.9899%
# Cross Validation Accuracy = 76.8452%
# Cross Validation Accuracy = 76.5557%
# Cross Validation Accuracy = 69.1751%
# Cross Validation Accuracy = 76.9899%
# Cross Validation Accuracy = 77.2793%
# Cross Validation Accuracy = 76.9899%
# Cross Validation Accuracy = 66.2808%
# Cross Validation Accuracy = 77.5687%
# Cross Validation Accuracy = 77.1346%
# Cross Validation Accuracy = 75.9768%
# Cross Validation Accuracy = 68.3068%
# Cross Validation Accuracy = 76.411%
# Cross Validation Accuracy = 76.8452%
# Cross Validation Accuracy = 76.1216%
# Cross Validation Accuracy = 67.8726%
# Cross Validation Accuracy = 77.2793%
# Cross Validation Accuracy = 77.1346%
# Cross Validation Accuracy = 76.9899%
# Cross Validation Accuracy = 69.754%
# Cross Validation Accuracy = 77.2793%
# Cross Validation Accuracy = 77.2793%
# Cross Validation Accuracy = 77.424%
# Cross Validation Accuracy = 66.2808%
# Cross Validation Accuracy = 76.1216%
# Cross Validation Accuracy = 78.1476%
# Cross Validation Accuracy = 76.411%
# Cross Validation Accuracy = 68.1621%
# Cross Validation Accuracy = 76.7004%
# Cross Validation Accuracy = 76.9899%
# Cross Validation Accuracy = 76.9899%
# Cross Validation Accuracy = 67.4385%
# Cross Validation Accuracy = 74.2402%
# Cross Validation Accuracy = 76.8452%
# Cross Validation Accuracy = 77.5687%
# Cross Validation Accuracy = 66.5702%
# Cross Validation Accuracy = 77.424%
# Cross Validation Accuracy = 76.5557%
# Cross Validation Accuracy = 74.0955%
# Cross Validation Accuracy = 70.4776%
# Cross Validation Accuracy = 76.5557%
# Cross Validation Accuracy = 77.1346%
# Cross Validation Accuracy = 73.9508%
# Cross Validation Accuracy = 67.7279%
# Cross Validation Accuracy = 76.9899%
# Cross Validation Accuracy = 76.8452%
# Cross Validation Accuracy = 73.3719%
# Cross Validation Accuracy = 67.4385%
# Cross Validation Accuracy = 77.1346%
# Cross Validation Accuracy = 76.9899%
# Cross Validation Accuracy = 73.0825%
# Cross Validation Accuracy = 68.5962%
# Cross Validation Accuracy = 77.1346%
# Cross Validation Accuracy = 77.1346%
# Cross Validation Accuracy = 73.9508%
# Cross Validation Accuracy = 67.0043%
# Cross Validation Accuracy = 75.9768%
# Cross Validation Accuracy = 76.5557%
# Cross Validation Accuracy = 71.3459%
# Cross Validation Accuracy = 67.0043%
# Cross Validation Accuracy = 77.5687%
# Cross Validation Accuracy = 76.7004%
# Cross Validation Accuracy = 70.9117%
# Cross Validation Accuracy = 67.0043%
# Cross Validation Accuracy = 78.0029%
# Cross Validation Accuracy = 77.424%
# Cross Validation Accuracy = 76.2663%
# Cross Validation Accuracy = 69.3198%
# Cross Validation Accuracy = 77.8582%
# Cross Validation Accuracy = 76.9899%
# Cross Validation Accuracy = 76.411%
# Cross Validation Accuracy = 68.5962%
# Cross Validation Accuracy = 77.1346%
# Cross Validation Accuracy = 76.2663%
# Cross Validation Accuracy = 72.7931%
# Cross Validation Accuracy = 67.7279%
# Cross Validation Accuracy = 76.8452%
# Cross Validation Accuracy = 76.5557%
# Cross Validation Accuracy = 71.9247%
# Cross Validation Accuracy = 66.4255%
# Cross Validation Accuracy = 75.8321%
# Cross Validation Accuracy = 77.1346%
# Cross Validation Accuracy = 76.7004%
# Cross Validation Accuracy = 68.8857%
# Cross Validation Accuracy = 76.8452%
# Cross Validation Accuracy = 76.5557%
# Cross Validation Accuracy = 77.424%
# Cross Validation Accuracy = 67.4385%
# Cross Validation Accuracy = 76.9899%
# Cross Validation Accuracy = 76.2663%
# Cross Validation Accuracy = 76.1216%
# Cross Validation Accuracy = 68.4515%
# Cross Validation Accuracy = 77.1346%
# Cross Validation Accuracy = 77.1346%
# Cross Validation Accuracy = 75.6874%
# Cross Validation Accuracy = 68.3068%
# Cross Validation Accuracy = 77.5687%
# Cross Validation Accuracy = 76.9899%
# Cross Validation Accuracy = 75.9768%
# Cross Validation Accuracy = 67.1491%
# Cross Validation Accuracy = 77.5687%
# Cross Validation Accuracy = 77.7135%
# Cross Validation Accuracy = 75.5427%
# Cross Validation Accuracy = 69.6093%
# Cross Validation Accuracy = 76.9899%
# Cross Validation Accuracy = 76.8452%
# Cross Validation Accuracy = 76.5557%
# Cross Validation Accuracy = 66.4255%
# Cross Validation Accuracy = 76.1216%
# Cross Validation Accuracy = 76.8452%
# Cross Validation Accuracy = 77.2793%
# Cross Validation Accuracy = 65.123%
# Cross Validation Accuracy = 77.8582%
# Cross Validation Accuracy = 76.2663%
# Cross Validation Accuracy = 71.6353%
# Cross Validation Accuracy = 78.1476%
# Cross Validation Accuracy = 77.424%
# Cross Validation Accuracy = 77.1346%
# Cross Validation Accuracy = 75.2533%
# Cross Validation Accuracy = 76.7004%
# Cross Validation Accuracy = 78.1476%
# Cross Validation Accuracy = 78.0029%
# Cross Validation Accuracy = 77.2793%
# Cross Validation Accuracy = 75.1085%
# Cross Validation Accuracy = 77.424%
# Cross Validation Accuracy = 77.2793%
# Cross Validation Accuracy = 77.424%
# Cross Validation Accuracy = 75.8321%
# Cross Validation Accuracy = 77.5687%
# Cross Validation Accuracy = 77.7135%
# Cross Validation Accuracy = 77.424%
# Cross Validation Accuracy = 74.3849%
# Cross Validation Accuracy = 77.7135%
# Cross Validation Accuracy = 77.7135%
# Cross Validation Accuracy = 77.5687%
# Cross Validation Accuracy = 74.2402%
# Cross Validation Accuracy = 78.0029%
# Cross Validation Accuracy = 78.1476%
# Cross Validation Accuracy = 77.1346%
# Cross Validation Accuracy = 74.3849%
# Cross Validation Accuracy = 76.9899%
# Cross Validation Accuracy = 77.424%
# Cross Validation Accuracy = 78.0029%
# Cross Validation Accuracy = 75.6874%
# Cross Validation Accuracy = 76.9899%
# Cross Validation Accuracy = 76.411%
# Cross Validation Accuracy = 77.2793%
# Cross Validation Accuracy = 75.8321%
# Cross Validation Accuracy = 78.1476%
# Cross Validation Accuracy = 76.9899%
# Cross Validation Accuracy = 77.7135%
# Cross Validation Accuracy = 77.1346%
# Cross Validation Accuracy = 76.9899%
# Cross Validation Accuracy = 77.2793%
# Cross Validation Accuracy = 74.6744%
# Cross Validation Accuracy = 77.8582%
# Cross Validation Accuracy = 76.9899%
# Cross Validation Accuracy = 77.424%
# Cross Validation Accuracy = 77.424%
# Cross Validation Accuracy = 74.9638%
# Cross Validation Accuracy = 77.2793%
# Cross Validation Accuracy = 76.411%
# Cross Validation Accuracy = 77.424%
# Cross Validation Accuracy = 74.3849%
# Cross Validation Accuracy = 76.9899%
# Cross Validation Accuracy = 77.7135%
# Cross Validation Accuracy = 76.5557%
# Cross Validation Accuracy = 71.2012%
# Cross Validation Accuracy = 77.7135%
# Cross Validation Accuracy = 77.5687%
# Cross Validation Accuracy = 77.424%
# Cross Validation Accuracy = 74.6744%
# Cross Validation Accuracy = 76.9899%
# Cross Validation Accuracy = 77.7135%
# Cross Validation Accuracy = 76.5557%
# Cross Validation Accuracy = 70.6223%
# Cross Validation Accuracy = 76.8452%
# Cross Validation Accuracy = 76.9899%
# Cross Validation Accuracy = 77.5687%
# Cross Validation Accuracy = 73.6614%
# Cross Validation Accuracy = 75.6874%
# Cross Validation Accuracy = 76.5557%
# Cross Validation Accuracy = 78.0029%
# Cross Validation Accuracy = 70.0434%
# Cross Validation Accuracy = 78.0029%
# Cross Validation Accuracy = 76.9899%
# Cross Validation Accuracy = 78.8712%
# Cross Validation Accuracy = 69.4645%
# Cross Validation Accuracy = 76.7004%
# Cross Validation Accuracy = 76.9899%
# Cross Validation Accuracy = 77.424%
# Cross Validation Accuracy = 71.9247%
# Cross Validation Accuracy = 77.2793%
# Cross Validation Accuracy = 76.5557%
# Cross Validation Accuracy = 76.9899%
# Cross Validation Accuracy = 71.6353%
# Cross Validation Accuracy = 76.8452%
# Cross Validation Accuracy = 75.5427%
# Cross Validation Accuracy = 77.424%
# Cross Validation Accuracy = 70.6223%
# Cross Validation Accuracy = 77.2793%
# Cross Validation Accuracy = 77.5687%
# Cross Validation Accuracy = 76.2663%
# Cross Validation Accuracy = 69.4645%
# Cross Validation Accuracy = 78.2923%
# Cross Validation Accuracy = 78.1476%
# Cross Validation Accuracy = 74.8191%
# Cross Validation Accuracy = 69.3198%
# Cross Validation Accuracy = 75.6874%
# Cross Validation Accuracy = 77.424%
# Cross Validation Accuracy = 74.8191%
# Cross Validation Accuracy = 69.1751%
# Cross Validation Accuracy = 77.7135%
# Cross Validation Accuracy = 76.7004%
# Cross Validation Accuracy = 75.2533%
# Cross Validation Accuracy = 70.3329%
# Cross Validation Accuracy = 77.8582%
# Cross Validation Accuracy = 76.1216%
# Cross Validation Accuracy = 76.2663%
# Cross Validation Accuracy = 68.741%
# Cross Validation Accuracy = 77.1346%
# Cross Validation Accuracy = 76.8452%
# Cross Validation Accuracy = 75.5427%
# Cross Validation Accuracy = 67.7279%
# Cross Validation Accuracy = 77.5687%
# Cross Validation Accuracy = 75.9768%
# Cross Validation Accuracy = 77.7135%
# Cross Validation Accuracy = 67.8726%
# Cross Validation Accuracy = 76.9899%
# Cross Validation Accuracy = 77.7135%
# Cross Validation Accuracy = 75.5427%
# Cross Validation Accuracy = 67.7279%
# Cross Validation Accuracy = 76.9899%
# Cross Validation Accuracy = 77.7135%
# Cross Validation Accuracy = 76.9899%
# Cross Validation Accuracy = 67.7279%
# Cross Validation Accuracy = 77.8582%
# Cross Validation Accuracy = 76.8452%
# Cross Validation Accuracy = 75.8321%
# Cross Validation Accuracy = 69.0304%
# Cross Validation Accuracy = 78.1476%
# Cross Validation Accuracy = 77.424%
# Cross Validation Accuracy = 75.1085%
# Cross Validation Accuracy = 70.4776%
# Cross Validation Accuracy = 78.0029%
# Cross Validation Accuracy = 77.1346%
# Cross Validation Accuracy = 74.0955%
# Cross Validation Accuracy = 68.4515%
# Cross Validation Accuracy = 77.1346%
# Cross Validation Accuracy = 77.424%
# Cross Validation Accuracy = 76.5557%
# Cross Validation Accuracy = 66.136%
# Cross Validation Accuracy = 77.2793%
# Cross Validation Accuracy = 76.8452%
# Cross Validation Accuracy = 73.2272%
# Cross Validation Accuracy = 67.5832%
# Cross Validation Accuracy = 77.2793%
# Cross Validation Accuracy = 76.5557%
# Cross Validation Accuracy = 73.8061%
# Cross Validation Accuracy = 67.7279%
# Cross Validation Accuracy = 77.7135%
# Cross Validation Accuracy = 76.7004%
# Cross Validation Accuracy = 74.3849%
# Cross Validation Accuracy = 67.1491%
# Cross Validation Accuracy = 78.1476%
# Cross Validation Accuracy = 76.2663%
# Cross Validation Accuracy = 74.8191%
# Cross Validation Accuracy = 68.741%
# Cross Validation Accuracy = 76.9899%
# Cross Validation Accuracy = 77.8582%
# Cross Validation Accuracy = 75.9768%
# Cross Validation Accuracy = 68.8857%
# Cross Validation Accuracy = 76.1216%
# Cross Validation Accuracy = 77.7135%
# Cross Validation Accuracy = 77.1346%
# Cross Validation Accuracy = 68.5962%
# Cross Validation Accuracy = 77.7135%
# Cross Validation Accuracy = 75.398%
# Cross Validation Accuracy = 78.0029%
# Cross Validation Accuracy = 68.4515%
# Cross Validation Accuracy = 78.1476%
# Cross Validation Accuracy = 77.424%
# Cross Validation Accuracy = 76.411%
# Cross Validation Accuracy = 69.754%
# Cross Validation Accuracy = 77.5687%
# Cross Validation Accuracy = 78.1476%
# Cross Validation Accuracy = 75.6874%
# Cross Validation Accuracy = 69.754%
# Cross Validation Accuracy = 77.1346%
# Cross Validation Accuracy = 76.7004%
# Cross Validation Accuracy = 76.5557%
# Cross Validation Accuracy = 67.4385%
# Cross Validation Accuracy = 76.8452%
# Cross Validation Accuracy = 77.8582%
# Cross Validation Accuracy = 77.7135%
# Cross Validation Accuracy = 69.4645%
# Cross Validation Accuracy = 77.8582%
# Cross Validation Accuracy = 75.5427%
# Cross Validation Accuracy = 78.2923%
# Cross Validation Accuracy = 68.0174%
# Cross Validation Accuracy = 76.8452%
# Cross Validation Accuracy = 78.0029%
# Cross Validation Accuracy = 74.9638%
# Cross Validation Accuracy = 68.8857%
# Cross Validation Accuracy = 76.9899%
# Cross Validation Accuracy = 76.8452%
# Cross Validation Accuracy = 77.1346%
# Cross Validation Accuracy = 69.1751%
# Cross Validation Accuracy = 75.6874%
# Cross Validation Accuracy = 76.8452%
# Cross Validation Accuracy = 76.7004%
# Cross Validation Accuracy = 68.1621%
# Cross Validation Accuracy = 75.398%
# Cross Validation Accuracy = 77.2793%
# Cross Validation Accuracy = 77.8582%
# Cross Validation Accuracy = 67.5832%
# Cross Validation Accuracy = 77.1346%
# Cross Validation Accuracy = 77.424%
# Cross Validation Accuracy = 77.2793%
# Cross Validation Accuracy = 66.7149%
# Cross Validation Accuracy = 77.2793%
# Cross Validation Accuracy = 76.411%
# Cross Validation Accuracy = 76.1216%
# Cross Validation Accuracy = 68.5962%
# Cross Validation Accuracy = 77.5687%
# Cross Validation Accuracy = 77.2793%
# Cross Validation Accuracy = 75.5427%
# Cross Validation Accuracy = 70.1881%
# Cross Validation Accuracy = 77.7135%
# Cross Validation Accuracy = 77.8582%
# Cross Validation Accuracy = 76.1216%
# Cross Validation Accuracy = 66.8596%
# Cross Validation Accuracy = 78.437%
# Cross Validation Accuracy = 77.7135%
# Cross Validation Accuracy = 76.1216%
# Cross Validation Accuracy = 69.754%
# Cross Validation Accuracy = 76.9899%
# Cross Validation Accuracy = 76.9899%
# Cross Validation Accuracy = 76.1216%
# Cross Validation Accuracy = 64.8336%
# Cross Validation Accuracy = 77.5687%
# Cross Validation Accuracy = 76.7004%
# Cross Validation Accuracy = 75.6874%
# Cross Validation Accuracy = 66.5702%
# Cross Validation Accuracy = 77.5687%
# Cross Validation Accuracy = 78.437%
# Cross Validation Accuracy = 76.7004%
# Cross Validation Accuracy = 67.4385%
# Cross Validation Accuracy = 77.5687%
# Cross Validation Accuracy = 77.424%
# Cross Validation Accuracy = 75.9768%
# Cross Validation Accuracy = 67.5832%
# Cross Validation Accuracy = 77.2793%
# Cross Validation Accuracy = 77.424%
# Cross Validation Accuracy = 74.5297%
# Cross Validation Accuracy = 66.8596%
# Cross Validation Accuracy = 76.9899%
# Cross Validation Accuracy = 77.5687%
# Cross Validation Accuracy = 74.6744%
# Cross Validation Accuracy = 69.8987%
# Cross Validation Accuracy = 77.7135%
# Cross Validation Accuracy = 77.5687%
# Cross Validation Accuracy = 75.6874%
# Cross Validation Accuracy = 67.1491%
# Cross Validation Accuracy = 76.411%
# Cross Validation Accuracy = 77.7135%
# Cross Validation Accuracy = 76.5557%
# Cross Validation Accuracy = 67.1491%
# Cross Validation Accuracy = 76.9899%
# Cross Validation Accuracy = 76.9899%
# Cross Validation Accuracy = 76.8452%
# Cross Validation Accuracy = 69.1751%
# Cross Validation Accuracy = 76.5557%
# Cross Validation Accuracy = 75.6874%
# Cross Validation Accuracy = 77.8582%
# Cross Validation Accuracy = 68.0174%
# Cross Validation Accuracy = 77.2793%
# Cross Validation Accuracy = 77.7135%
# Cross Validation Accuracy = 76.7004%
# Cross Validation Accuracy = 69.3198%
# Cross Validation Accuracy = 77.7135%
# Cross Validation Accuracy = 78.1476%
# Cross Validation Accuracy = 75.2533%
# Cross Validation Accuracy = 67.8726%
# Cross Validation Accuracy = 77.1346%
# Cross Validation Accuracy = 77.424%
# Cross Validation Accuracy = 75.9768%
# Cross Validation Accuracy = 66.8596%
# Cross Validation Accuracy = 77.8582%
# Cross Validation Accuracy = 76.9899%
# Cross Validation Accuracy = 76.411%
# Cross Validation Accuracy = 66.5702%
# Cross Validation Accuracy = 77.7135%
# Cross Validation Accuracy = 77.1346%
# Cross Validation Accuracy = 77.7135%
# Cross Validation Accuracy = 69.3198%
# Cross Validation Accuracy = 77.2793%
# Cross Validation Accuracy = 76.8452%
# Cross Validation Accuracy = 76.9899%
# Cross Validation Accuracy = 67.1491%
# Cross Validation Accuracy = 76.9899%
# Cross Validation Accuracy = 77.1346%
# Cross Validation Accuracy = 77.5687%
# Cross Validation Accuracy = 68.8857%
# Cross Validation Accuracy = 76.5557%
# Cross Validation Accuracy = 76.9899%
# Cross Validation Accuracy = 77.7135%
# Cross Validation Accuracy = 70.1881%
# Cross Validation Accuracy = 77.424%
# Cross Validation Accuracy = 77.7135%
# Cross Validation Accuracy = 75.8321%
# Cross Validation Accuracy = 67.2938%
# Cross Validation Accuracy = 77.2793%
# Cross Validation Accuracy = 78.8712%
# Cross Validation Accuracy = 75.8321%
# Cross Validation Accuracy = 70.1881%
# Cross Validation Accuracy = 76.9899%
# Cross Validation Accuracy = 76.9899%
# Cross Validation Accuracy = 75.8321%
# Cross Validation Accuracy = 69.4645%
# Cross Validation Accuracy = 76.5557%
# Cross Validation Accuracy = 77.7135%
# Cross Validation Accuracy = 72.9378%
# Cross Validation Accuracy = 68.1621%
# Cross Validation Accuracy = 77.5687%
# Cross Validation Accuracy = 77.5687%
# Cross Validation Accuracy = 75.398%
# Cross Validation Accuracy = 70.0434%
# Cross Validation Accuracy = 77.7135%
# Cross Validation Accuracy = 77.424%
# Cross Validation Accuracy = 74.6744%
# Cross Validation Accuracy = 68.3068%
# Cross Validation Accuracy = 78.1476%
# Cross Validation Accuracy = 77.7135%
# Cross Validation Accuracy = 76.1216%
# Cross Validation Accuracy = 68.741%
# Cross Validation Accuracy = 77.2793%
# Cross Validation Accuracy = 77.424%
# Cross Validation Accuracy = 76.7004%
# Cross Validation Accuracy = 69.3198%
# Cross Validation Accuracy = 78.0029%
# Cross Validation Accuracy = 76.7004%
# Cross Validation Accuracy = 76.5557%
# Cross Validation Accuracy = 68.5962%
# Cross Validation Accuracy = 78.1476%
# Cross Validation Accuracy = 77.7135%
# Cross Validation Accuracy = 77.424%
# Cross Validation Accuracy = 68.0174%
# Cross Validation Accuracy = 77.8582%
# Cross Validation Accuracy = 77.2793%
# Cross Validation Accuracy = 77.424%
# Cross Validation Accuracy = 70.4776%
# Cross Validation Accuracy = 76.8452%
# Cross Validation Accuracy = 75.5427%
# Cross Validation Accuracy = 77.424%
# Cross Validation Accuracy = 68.3068%
# Cross Validation Accuracy = 78.437%
# Cross Validation Accuracy = 77.424%
# Cross Validation Accuracy = 76.411%
# Cross Validation Accuracy = 67.1491%
# Cross Validation Accuracy = 77.7135%
# Cross Validation Accuracy = 77.424%
# Cross Validation Accuracy = 76.9899%
# Cross Validation Accuracy = 69.754%
# Cross Validation Accuracy = 77.8582%
# Cross Validation Accuracy = 77.7135%
# Cross Validation Accuracy = 75.5427%
# Cross Validation Accuracy = 68.3068%
# Cross Validation Accuracy = 77.1346%
# Cross Validation Accuracy = 76.8452%
# Cross Validation Accuracy = 78.0029%
# Cross Validation Accuracy = 69.1751%
# Cross Validation Accuracy = 77.5687%
# Cross Validation Accuracy = 76.8452%
# Cross Validation Accuracy = 77.5687%
# Cross Validation Accuracy = 69.8987%
# Cross Validation Accuracy = 77.5687%
# Cross Validation Accuracy = 78.0029%
# Cross Validation Accuracy = 76.8452%
# Cross Validation Accuracy = 70.767%
# Cross Validation Accuracy = 77.1346%
# Cross Validation Accuracy = 76.9899%
# Cross Validation Accuracy = 76.7004%
# Cross Validation Accuracy = 69.754%
# Cross Validation Accuracy = 77.1346%
# Cross Validation Accuracy = 77.7135%
# Cross Validation Accuracy = 77.424%
# Cross Validation Accuracy = 72.3589%
# Cross Validation Accuracy = 76.8452%
# Cross Validation Accuracy = 77.1346%
# Cross Validation Accuracy = 77.5687%
# Cross Validation Accuracy = 71.3459%
# Cross Validation Accuracy = 77.424%
# Cross Validation Accuracy = 78.2923%
# Cross Validation Accuracy = 77.8582%
# Cross Validation Accuracy = 69.0304%
# Cross Validation Accuracy = 77.7135%
# Cross Validation Accuracy = 76.8452%
# Cross Validation Accuracy = 78.1476%
# Cross Validation Accuracy = 68.8857%
# Cross Validation Accuracy = 78.437%
# Cross Validation Accuracy = 78.1476%
# Cross Validation Accuracy = 76.2663%
# Cross Validation Accuracy = 72.6483%
# Cross Validation Accuracy = 77.1346%
# Cross Validation Accuracy = 76.411%
# Cross Validation Accuracy = 76.2663%
# Cross Validation Accuracy = 72.0695%
# Cross Validation Accuracy = 77.1346%
# Cross Validation Accuracy = 76.5557%
# Cross Validation Accuracy = 76.411%
# Cross Validation Accuracy = 69.4645%
# Cross Validation Accuracy = 77.7135%
# Cross Validation Accuracy = 77.5687%
# Cross Validation Accuracy = 76.9899%
# Cross Validation Accuracy = 67.1491%
# Cross Validation Accuracy = 77.7135%
# Cross Validation Accuracy = 78.437%
# Cross Validation Accuracy = 75.9768%
# Cross Validation Accuracy = 67.7279%
# Cross Validation Accuracy = 77.5687%
# Cross Validation Accuracy = 77.424%
# Cross Validation Accuracy = 76.8452%
# Cross Validation Accuracy = 68.5962%
# Cross Validation Accuracy = 76.411%
# Cross Validation Accuracy = 77.7135%
# Cross Validation Accuracy = 75.398%
# Cross Validation Accuracy = 69.754%
# Cross Validation Accuracy = 77.424%
# Cross Validation Accuracy = 78.2923%
# Cross Validation Accuracy = 73.8061%
# Cross Validation Accuracy = 67.5832%
# Cross Validation Accuracy = 77.424%
# Cross Validation Accuracy = 77.1346%
# Cross Validation Accuracy = 75.2533%
# Cross Validation Accuracy = 69.0304%
# Cross Validation Accuracy = 75.8321%
# Cross Validation Accuracy = 78.0029%
# Cross Validation Accuracy = 75.8321%
# Cross Validation Accuracy = 69.1751%
# Cross Validation Accuracy = 76.9899%
# Cross Validation Accuracy = 77.424%
# Cross Validation Accuracy = 75.9768%
# Cross Validation Accuracy = 68.741%
# Cross Validation Accuracy = 76.5557%
# Cross Validation Accuracy = 76.1216%
# Cross Validation Accuracy = 77.1346%
# Cross Validation Accuracy = 67.5832%
# Cross Validation Accuracy = 77.1346%
# Cross Validation Accuracy = 78.0029%
# Cross Validation Accuracy = 77.2793%
# Cross Validation Accuracy = 69.4645%
# Cross Validation Accuracy = 77.2793%
# Cross Validation Accuracy = 77.5687%
# Cross Validation Accuracy = 76.411%
# Cross Validation Accuracy = 68.1621%
# Cross Validation Accuracy = 77.5687%
# Cross Validation Accuracy = 77.2793%
# Cross Validation Accuracy = 77.1346%
# Cross Validation Accuracy = 69.1751%
# Cross Validation Accuracy = 77.7135%
# Cross Validation Accuracy = 77.8582%
# Cross Validation Accuracy = 76.7004%
# Cross Validation Accuracy = 71.2012%
# Cross Validation Accuracy = 77.424%
# Cross Validation Accuracy = 77.2793%
# Cross Validation Accuracy = 76.2663%
# Cross Validation Accuracy = 67.7279%
# Cross Validation Accuracy = 77.5687%
# Cross Validation Accuracy = 77.5687%
# Cross Validation Accuracy = 78.1476%
# Cross Validation Accuracy = 69.8987%
# Cross Validation Accuracy = 76.5557%
# Cross Validation Accuracy = 77.8582%
# Cross Validation Accuracy = 78.437%
# Cross Validation Accuracy = 67.7279%
# Cross Validation Accuracy = 78.1476%
# Cross Validation Accuracy = 77.8582%
# Cross Validation Accuracy = 78.0029%
# Cross Validation Accuracy = 68.3068%
# Cross Validation Accuracy = 77.5687%
# Cross Validation Accuracy = 78.0029%
# Cross Validation Accuracy = 76.9899%
# Cross Validation Accuracy = 66.8596%
# Cross Validation Accuracy = 76.9899%
# Cross Validation Accuracy = 77.5687%
# Cross Validation Accuracy = 76.9899%
# Cross Validation Accuracy = 67.1491%
# Cross Validation Accuracy = 77.5687%
# Cross Validation Accuracy = 77.1346%
# Cross Validation Accuracy = 77.8582%
# Cross Validation Accuracy = 68.1621%
# Cross Validation Accuracy = 77.424%
# Cross Validation Accuracy = 78.0029%
# Cross Validation Accuracy = 77.7135%
# Cross Validation Accuracy = 69.3198%
# Cross Validation Accuracy = 76.9899%
# Cross Validation Accuracy = 76.7004%
# Cross Validation Accuracy = 77.7135%
# Cross Validation Accuracy = 69.6093%
# Cross Validation Accuracy = 77.5687%
# Cross Validation Accuracy = 77.5687%
# Cross Validation Accuracy = 77.7135%
# Cross Validation Accuracy = 66.7149%
# Cross Validation Accuracy = 76.2663%
# ...
# Cross Validation Accuracy = 70.9538%
# Cross Validation Accuracy = 65.0289%
# Cross Validation Accuracy = 65.3179%
# Cross Validation Accuracy = 74.8555%
# Cross Validation Accuracy = 69.5087%
# Cross Validation Accuracy = 65.0289%
# Cross Validation Accuracy = 65.0289%
# Cross Validation Accuracy = 75.289%
# Cross Validation Accuracy = 68.2081%
# Cross Validation Accuracy = 65.0289%
# Cross Validation Accuracy = 65.0289%
# Cross Validation Accuracy = 75%
# Cross Validation Accuracy = 70.8092%
# Cross Validation Accuracy = 65.1734%
# Cross Validation Accuracy = 65.0289%
# Cross Validation Accuracy = 76.7341%
# Cross Validation Accuracy = 70.8092%
# Cross Validation Accuracy = 65.0289%
# Cross Validation Accuracy = 65.0289%
# Cross Validation Accuracy = 76.1561%
# Cross Validation Accuracy = 67.7746%
# Cross Validation Accuracy = 65.0289%
# Cross Validation Accuracy = 65.0289%
# Cross Validation Accuracy = 74.8555%
# Cross Validation Accuracy = 67.341%
# Cross Validation Accuracy = 65.0289%
# Cross Validation Accuracy = 65.0289%
# Cross Validation Accuracy = 74.8555%
# Cross Validation Accuracy = 66.474%
# Cross Validation Accuracy = 65.0289%
# Cross Validation Accuracy = 65.0289%
# Cross Validation Accuracy = 75.4335%
# Cross Validation Accuracy = 68.4971%
# Cross Validation Accuracy = 65.0289%
# Cross Validation Accuracy = 65.0289%
# Cross Validation Accuracy = 74.8555%
# Cross Validation Accuracy = 69.5087%
# Cross Validation Accuracy = 65.0289%
# Cross Validation Accuracy = 65.0289%
# Cross Validation Accuracy = 73.6994%
# Cross Validation Accuracy = 67.6301%
# Cross Validation Accuracy = 65.0289%
# Cross Validation Accuracy = 65.0289%
# Cross Validation Accuracy = 75.4335%
# Cross Validation Accuracy = 67.6301%
# Cross Validation Accuracy = 65.0289%
# Cross Validation Accuracy = 65.0289%
# Cross Validation Accuracy = 75%
# Cross Validation Accuracy = 69.6532%
# Cross Validation Accuracy = 65.0289%
# Cross Validation Accuracy = 65.0289%
# Cross Validation Accuracy = 76.4451%
# Cross Validation Accuracy = 67.4855%
# Cross Validation Accuracy = 65.0289%
# Cross Validation Accuracy = 65.0289%
# Cross Validation Accuracy = 76.0116%
# Cross Validation Accuracy = 68.9306%
# Cross Validation Accuracy = 65.0289%
# Cross Validation Accuracy = 65.0289%
# Cross Validation Accuracy = 76.7341%
# Cross Validation Accuracy = 66.6185%
# Cross Validation Accuracy = 65.0289%
# Cross Validation Accuracy = 65.0289%
# Cross Validation Accuracy = 77.8902%
# Cross Validation Accuracy = 70.5202%
# Cross Validation Accuracy = 65.0289%
# Cross Validation Accuracy = 65.0289%
# Cross Validation Accuracy = 76.4451%
# Cross Validation Accuracy = 67.9191%
# Cross Validation Accuracy = 65.0289%
# Cross Validation Accuracy = 65.0289%
# Cross Validation Accuracy = 77.4566%
# Cross Validation Accuracy = 67.6301%
# Cross Validation Accuracy = 65.0289%
# Cross Validation Accuracy = 65.0289%
# Cross Validation Accuracy = 75.4335%
# Cross Validation Accuracy = 68.4971%
# Cross Validation Accuracy = 65.0289%
# Cross Validation Accuracy = 65.0289%
# Cross Validation Accuracy = 76.0116%
# Cross Validation Accuracy = 68.2081%
# Cross Validation Accuracy = 65.0289%
# Cross Validation Accuracy = 65.0289%
# Cross Validation Accuracy = 78.3237%
# Cross Validation Accuracy = 68.7861%
# Cross Validation Accuracy = 65.0289%
# Cross Validation Accuracy = 65.0289%
# Cross Validation Accuracy = 77.1676%
# Cross Validation Accuracy = 69.6532%
# Cross Validation Accuracy = 65.0289%
# Cross Validation Accuracy = 65.0289%
# Cross Validation Accuracy = 76.7341%
# Cross Validation Accuracy = 70.0867%
# Cross Validation Accuracy = 65.0289%
# Cross Validation Accuracy = 65.0289%
# Cross Validation Accuracy = 76.3006%
# Cross Validation Accuracy = 67.6301%
# Cross Validation Accuracy = 65.0289%
# Cross Validation Accuracy = 65.0289%
# Cross Validation Accuracy = 76.3006%
# Cross Validation Accuracy = 72.3988%
# Cross Validation Accuracy = 65.0289%
# Cross Validation Accuracy = 65.0289%
# Cross Validation Accuracy = 76.7341%
# Cross Validation Accuracy = 72.2543%
# Cross Validation Accuracy = 65.0289%
# Cross Validation Accuracy = 65.0289%
# Cross Validation Accuracy = 77.4566%
# Cross Validation Accuracy = 75.1445%
# Cross Validation Accuracy = 65.0289%
# Cross Validation Accuracy = 65.0289%
# Cross Validation Accuracy = 76.7341%
# Cross Validation Accuracy = 73.5549%
# Cross Validation Accuracy = 65.0289%
# Cross Validation Accuracy = 65.0289%
# Cross Validation Accuracy = 76.4451%
# Cross Validation Accuracy = 71.2428%
# Cross Validation Accuracy = 65.0289%
# Cross Validation Accuracy = 65.0289%
# Cross Validation Accuracy = 76.4451%
# Cross Validation Accuracy = 72.2543%
# Cross Validation Accuracy = 65.0289%
# Cross Validation Accuracy = 65.0289%
# Cross Validation Accuracy = 76.0116%
# Cross Validation Accuracy = 66.474%
# Cross Validation Accuracy = 65.0289%
# Cross Validation Accuracy = 65.0289%
# Cross Validation Accuracy = 76.3006%
# Cross Validation Accuracy = 67.7746%
# Cross Validation Accuracy = 65.0289%
# Cross Validation Accuracy = 65.0289%
# Cross Validation Accuracy = 75.7225%
# Cross Validation Accuracy = 66.6185%
# Cross Validation Accuracy = 65.0289%
# Cross Validation Accuracy = 65.0289%
# Cross Validation Accuracy = 76.1561%
# Cross Validation Accuracy = 68.6416%
# Cross Validation Accuracy = 65.0289%
# Cross Validation Accuracy = 65.0289%
# Cross Validation Accuracy = 76.1561%
# Cross Validation Accuracy = 67.1965%
# Cross Validation Accuracy = 65.0289%
# Cross Validation Accuracy = 65.0289%
# Cross Validation Accuracy = 77.3121%
# Cross Validation Accuracy = 66.763%
# Cross Validation Accuracy = 65.0289%
# Cross Validation Accuracy = 65.0289%
# Cross Validation Accuracy = 76.8786%
# Cross Validation Accuracy = 66.474%
# Cross Validation Accuracy = 65.0289%
# Cross Validation Accuracy = 65.0289%
# Cross Validation Accuracy = 76.8786%
# Cross Validation Accuracy = 67.052%
# Cross Validation Accuracy = 65.0289%
# Cross Validation Accuracy = 65.0289%
# Cross Validation Accuracy = 77.1676%
# Cross Validation Accuracy = 69.7977%
# Cross Validation Accuracy = 65.0289%
# Cross Validation Accuracy = 65.0289%
# Cross Validation Accuracy = 76.8786%
# Cross Validation Accuracy = 68.9306%
# Cross Validation Accuracy = 65.0289%
# Cross Validation Accuracy = 65.0289%
# Cross Validation Accuracy = 77.3121%
# Cross Validation Accuracy = 67.1965%
# Cross Validation Accuracy = 65.0289%
# Cross Validation Accuracy = 65.0289%
# Cross Validation Accuracy = 77.8902%
# Cross Validation Accuracy = 66.0405%
# Cross Validation Accuracy = 65.0289%
# Cross Validation Accuracy = 65.0289%
# Cross Validation Accuracy = 77.7457%
# Cross Validation Accuracy = 66.474%
# Cross Validation Accuracy = 65.0289%
# Cross Validation Accuracy = 65.0289%
# Cross Validation Accuracy = 76.1561%
# Cross Validation Accuracy = 67.052%
# Cross Validation Accuracy = 65.0289%
# Cross Validation Accuracy = 65.0289%
# Cross Validation Accuracy = 77.0231%
# Cross Validation Accuracy = 69.6532%
# Cross Validation Accuracy = 65.0289%
# Cross Validation Accuracy = 65.0289%
# Cross Validation Accuracy = 76.5896%
# Cross Validation Accuracy = 67.7746%
# Cross Validation Accuracy = 65.0289%
# Cross Validation Accuracy = 65.0289%
# Cross Validation Accuracy = 75.289%
# Cross Validation Accuracy = 67.6301%
# Cross Validation Accuracy = 65.0289%
# Cross Validation Accuracy = 65.0289%
# Cross Validation Accuracy = 75.289%
# Cross Validation Accuracy = 68.0636%
# Cross Validation Accuracy = 65.0289%
# Cross Validation Accuracy = 65.0289%
# Cross Validation Accuracy = 75.1445%
# Cross Validation Accuracy = 66.3295%
# Cross Validation Accuracy = 65.0289%
# Cross Validation Accuracy = 65.0289%
# Cross Validation Accuracy = 76.5896%
# Cross Validation Accuracy = 68.9306%
# Cross Validation Accuracy = 65.0289%
# Cross Validation Accuracy = 65.0289%
# Cross Validation Accuracy = 75.7225%
# Cross Validation Accuracy = 66.6185%
# Cross Validation Accuracy = 65.0289%
# Cross Validation Accuracy = 65.0289%
# Cross Validation Accuracy = 76.7341%
# Cross Validation Accuracy = 68.9306%
# Cross Validation Accuracy = 65.0289%
# Cross Validation Accuracy = 65.0289%
# Cross Validation Accuracy = 74.711%
# Cross Validation Accuracy = 67.6301%
# Cross Validation Accuracy = 67.341%
# Cross Validation Accuracy = 65.0289%
# Cross Validation Accuracy = 75.4335%
# Cross Validation Accuracy = 68.2081%
# Cross Validation Accuracy = 66.6185%
# Cross Validation Accuracy = 65.0289%
# Cross Validation Accuracy = 77.3121%
# Cross Validation Accuracy = 68.6416%
# Cross Validation Accuracy = 71.6763%
# Cross Validation Accuracy = 65.0289%
# Cross Validation Accuracy = 76.0116%
# Cross Validation Accuracy = 70.3757%
# Cross Validation Accuracy = 68.7861%
# Cross Validation Accuracy = 65.0289%
# Cross Validation Accuracy = 76.0116%
# Cross Validation Accuracy = 68.0636%
# Cross Validation Accuracy = 68.2081%
# Cross Validation Accuracy = 65.0289%
# Cross Validation Accuracy = 75.4335%
# Cross Validation Accuracy = 65.3179%
# Cross Validation Accuracy = 67.341%
# Cross Validation Accuracy = 65.0289%
# Cross Validation Accuracy = 75.4335%
# Cross Validation Accuracy = 75.8671%
# Cross Validation Accuracy = 69.3642%
# Cross Validation Accuracy = 65.0289%
# Cross Validation Accuracy = 76.0116%
# Cross Validation Accuracy = 73.9884%
# Cross Validation Accuracy = 67.1965%
# Cross Validation Accuracy = 65.0289%
# Cross Validation Accuracy = 74.5665%
# Cross Validation Accuracy = 75%
# Cross Validation Accuracy = 67.052%
# Cross Validation Accuracy = 65.0289%
# Cross Validation Accuracy = 75%
# Cross Validation Accuracy = 74.711%
# Cross Validation Accuracy = 66.6185%
# Cross Validation Accuracy = 65.0289%
# Cross Validation Accuracy = 74.2775%
# Cross Validation Accuracy = 77.1676%
# Cross Validation Accuracy = 71.0983%
# Cross Validation Accuracy = 65.0289%
# Cross Validation Accuracy = 77.6012%
# Cross Validation Accuracy = 77.1676%
# Cross Validation Accuracy = 66.6185%
# Cross Validation Accuracy = 65.0289%
# Cross Validation Accuracy = 77.8902%
# Cross Validation Accuracy = 75.7225%
# Cross Validation Accuracy = 68.4971%
# Cross Validation Accuracy = 65.0289%
# Cross Validation Accuracy = 77.3121%
# Cross Validation Accuracy = 76.0116%
# Cross Validation Accuracy = 67.6301%
# Cross Validation Accuracy = 65.0289%
# Cross Validation Accuracy = 77.8902%
# Cross Validation Accuracy = 76.8786%
# Cross Validation Accuracy = 66.474%
# Cross Validation Accuracy = 65.0289%
# Cross Validation Accuracy = 77.7457%
# Cross Validation Accuracy = 75.1445%
# Cross Validation Accuracy = 67.4855%
# Cross Validation Accuracy = 65.0289%
# Cross Validation Accuracy = 77.3121%
# Cross Validation Accuracy = 75.8671%
# Cross Validation Accuracy = 70.6647%
# Cross Validation Accuracy = 65.0289%
# Cross Validation Accuracy = 77.1676%
# Cross Validation Accuracy = 76.7341%
# Cross Validation Accuracy = 68.2081%
# Cross Validation Accuracy = 65.0289%
# Cross Validation Accuracy = 77.3121%
# Cross Validation Accuracy = 74.1329%
# Cross Validation Accuracy = 66.3295%
# Cross Validation Accuracy = 65.0289%
# Cross Validation Accuracy = 77.8902%
# Cross Validation Accuracy = 74.5665%
# Cross Validation Accuracy = 68.0636%
# Cross Validation Accuracy = 65.0289%
# Cross Validation Accuracy = 78.3237%
# Cross Validation Accuracy = 71.2428%
# Cross Validation Accuracy = 67.9191%
# Cross Validation Accuracy = 65.0289%
# Cross Validation Accuracy = 77.0231%
# Cross Validation Accuracy = 71.6763%
# Cross Validation Accuracy = 69.7977%
# Cross Validation Accuracy = 65.0289%
# Cross Validation Accuracy = 77.8902%
# Cross Validation Accuracy = 73.8439%
# Cross Validation Accuracy = 67.9191%
# Cross Validation Accuracy = 65.0289%
# Cross Validation Accuracy = 77.3121%
# Cross Validation Accuracy = 73.4104%
# Cross Validation Accuracy = 69.7977%
# Cross Validation Accuracy = 65.0289%
# Cross Validation Accuracy = 77.0231%
# Cross Validation Accuracy = 72.8324%
# Cross Validation Accuracy = 67.1965%
# Cross Validation Accuracy = 65.0289%
# Cross Validation Accuracy = 77.1676%
# Cross Validation Accuracy = 74.1329%
# Cross Validation Accuracy = 66.9075%
# Cross Validation Accuracy = 65.0289%
# Cross Validation Accuracy = 77.0231%
# Cross Validation Accuracy = 75.1445%
# Cross Validation Accuracy = 67.1965%
# Cross Validation Accuracy = 65.0289%
# Cross Validation Accuracy = 77.6012%
# Cross Validation Accuracy = 74.422%
# Cross Validation Accuracy = 68.0636%
# Cross Validation Accuracy = 65.0289%
# Cross Validation Accuracy = 76.3006%
# Cross Validation Accuracy = 75.289%
# Cross Validation Accuracy = 67.7746%
# Cross Validation Accuracy = 65.0289%
# Cross Validation Accuracy = 77.8902%
# Cross Validation Accuracy = 72.3988%
# Cross Validation Accuracy = 66.474%
# Cross Validation Accuracy = 65.0289%
# Cross Validation Accuracy = 76.4451%
# Cross Validation Accuracy = 74.422%
# Cross Validation Accuracy = 67.341%
# Cross Validation Accuracy = 65.0289%
# Cross Validation Accuracy = 77.1676%
# Cross Validation Accuracy = 73.4104%
# Cross Validation Accuracy = 65.0289%
# Cross Validation Accuracy = 65.0289%
# Cross Validation Accuracy = 76.1561%
# Cross Validation Accuracy = 73.5549%
# Cross Validation Accuracy = 68.9306%
# Cross Validation Accuracy = 65.0289%
# Cross Validation Accuracy = 76.5896%
# Cross Validation Accuracy = 73.2659%
# Cross Validation Accuracy = 67.1965%
# Cross Validation Accuracy = 65.0289%
# Cross Validation Accuracy = 75.7225%
# Cross Validation Accuracy = 74.2775%
# Cross Validation Accuracy = 67.4855%
# Cross Validation Accuracy = 65.0289%
# Cross Validation Accuracy = 76.4451%
# Cross Validation Accuracy = 73.2659%
# Cross Validation Accuracy = 67.1965%
# Cross Validation Accuracy = 65.0289%
# Cross Validation Accuracy = 77.7457%
# Cross Validation Accuracy = 74.422%
# Cross Validation Accuracy = 69.6532%
# Cross Validation Accuracy = 65.0289%
# Cross Validation Accuracy = 76.4451%
# Cross Validation Accuracy = 77.6012%
# Cross Validation Accuracy = 68.4971%
# Cross Validation Accuracy = 65.0289%
# Cross Validation Accuracy = 75%
# Cross Validation Accuracy = 77.6012%
# Cross Validation Accuracy = 70.2312%
# Cross Validation Accuracy = 65.0289%
# Cross Validation Accuracy = 75.578%
# Cross Validation Accuracy = 73.9884%
# Cross Validation Accuracy = 71.8208%
# Cross Validation Accuracy = 65.0289%
# Cross Validation Accuracy = 77.1676%
# Cross Validation Accuracy = 74.5665%
# Cross Validation Accuracy = 74.2775%
# Cross Validation Accuracy = 65.0289%
# Cross Validation Accuracy = 77.6012%
# Cross Validation Accuracy = 75.578%
# Cross Validation Accuracy = 73.2659%
# Cross Validation Accuracy = 65.0289%
# Cross Validation Accuracy = 75.8671%
# Cross Validation Accuracy = 73.5549%
# Cross Validation Accuracy = 71.3873%
# Cross Validation Accuracy = 65.0289%
# Cross Validation Accuracy = 75.7225%
# Cross Validation Accuracy = 73.6994%
# Cross Validation Accuracy = 71.8208%
# Cross Validation Accuracy = 65.0289%
# Cross Validation Accuracy = 75.4335%
# Cross Validation Accuracy = 75%
# Cross Validation Accuracy = 72.1098%
# Cross Validation Accuracy = 65.0289%
# Cross Validation Accuracy = 75.578%
# Cross Validation Accuracy = 73.8439%
# Cross Validation Accuracy = 72.3988%
# Cross Validation Accuracy = 65.0289%
# Cross Validation Accuracy = 75.289%
# Cross Validation Accuracy = 75.7225%
# Cross Validation Accuracy = 70.8092%
# Cross Validation Accuracy = 65.0289%
# Cross Validation Accuracy = 76.3006%
# Cross Validation Accuracy = 77.0231%
# Cross Validation Accuracy = 68.9306%
# Cross Validation Accuracy = 65.0289%
# Cross Validation Accuracy = 77.6012%
# Cross Validation Accuracy = 72.8324%
# Cross Validation Accuracy = 70.0867%
# Cross Validation Accuracy = 65.0289%
# Cross Validation Accuracy = 76.3006%
# Cross Validation Accuracy = 74.1329%
# Cross Validation Accuracy = 71.5318%
# Cross Validation Accuracy = 65.0289%
# Cross Validation Accuracy = 78.9017%
# Cross Validation Accuracy = 73.6994%
# Cross Validation Accuracy = 71.5318%
# Cross Validation Accuracy = 65.0289%
# Cross Validation Accuracy = 75.7225%
# Cross Validation Accuracy = 75.1445%
# Cross Validation Accuracy = 71.0983%
# Cross Validation Accuracy = 65.0289%
# Cross Validation Accuracy = 78.4682%
# Cross Validation Accuracy = 73.9884%
# Cross Validation Accuracy = 68.6416%
# Cross Validation Accuracy = 65.0289%
# Cross Validation Accuracy = 78.0347%
# Cross Validation Accuracy = 75.578%
# Cross Validation Accuracy = 68.6416%
# Cross Validation Accuracy = 65.0289%
# Cross Validation Accuracy = 77.3121%
# Cross Validation Accuracy = 74.8555%
# Cross Validation Accuracy = 67.1965%
# Cross Validation Accuracy = 65.0289%
# Accuracy: 0.7663 ± 0.0459
# AUC: 0.7630 ± 0.2050
# Sensitivity: 0.5469 ± 0.0993
# Specificity: 0.8838 ± 0.0479
